# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("LRUMLP_enc256_nr128_d128_MNIST_step3000r_min_0.9r_max0.999.csv")

# %%
data2=pd.read_csv("raw_tuned_r/LRUMLP1_H256_nr128_D128_MNIST_step3000r_min_0.9r_max0.999.csv")

# %%
plt.plot(data["step"],data["test_accuracy"],label="drop out&warm up")
plt.plot(data2["step"],data2["test_accuracy"],label="without")
plt.title("test accuracy of the two model")
plt.legend()
plt.show()
